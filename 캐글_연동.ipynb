# %% [markdown]
# # 캐글 연동 기초 작업
# ### 1. 라이브러리 다운
# ### 2. kaggle.jason 업로드

# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-8119f829-10e8-4977-9599-623fc4967855" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8119f829-10e8-4977-9599-623fc4967855">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle # create folder name Kaggle
# !cp kaggle.json ~/.kaggle/ # copy kaggle.json into folder Kaggle
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# # 디렉토리 설정

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/My Drive/data/.kaggle/"  # 'KAGGLE_CONFIG_DIR'에 저장될 환경변수 지정

# %% [markdown]
# ### 드라이브 마운트

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 디렉토리 이동

# %%
cd /content/drive/My Drive/data/.kaggle
# Out:
# /content/drive/My Drive/data/.kaggle

# %% [markdown]
# # 데이터 불러오기

# %% [markdown]
# ### 1. 다운하고자 하는 데이터 목록 확인

# %%
# !kaggle datasets list -s dog
# Out:
# ref                                         title                          size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------------  ----------------------------  -----  -------------------  -------------  ---------  ---------------
# tongpython/cat-and-dog                      Cat and Dog                   218MB  2018-04-26 10:56:50          79016        984  0.75
# dansbecker/hot-dog-not-hot-dog              Hot Dog - Not Hot Dog          89MB  2018-07-19 05:52:04           6149        118  0.625
# jessicali9530/stanford-dogs-dataset         Stanford Dogs Dataset         750MB  2019-11-13 06:20:35          36943        909  0.75
# marshuu/dog-breeds                          Dog breeds                      3KB  2022-12-20 18:49:43           1041         36  1.0
# shaunthesheep/microsoft-catsvsdogs-dataset  Cats-vs-Dogs                  788MB  2020-03-12 05:34:30          22526        306  0.875
# ...

# %% [markdown]
# ### 2. 데이터 ref 확인 및 다운

# %%
# !kaggle datasets download -d biaiscience/dogs-vs-cats
# Out:
# ...
# 100% 815M/817M [00:06<00:00, 133MB/s]
# 100% 817M/817M [00:06<00:00, 140MB/s]
